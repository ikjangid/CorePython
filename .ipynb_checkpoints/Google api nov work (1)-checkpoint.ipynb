# %%
import requests
key = "AIzaSyC9Fp6M6ygwcxWarFiNQEr6aJ7lV5DY"
place = input("Search a Place : ").strip().lower()
place  = place.replace(' ','%20')
url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={}&inputtype=textquery&fields=photos,formatted_address,name,rating,opening_hours,geometry&key={}".format(place,key)
page = requests.get(url)
# Out:
# Search a Place : ajmer

# %%
from pprint import pprint

# %%
page
# Out:
# <Response [200]>

# %%
data = page.json()

# %%
data
# Out:
# {'candidates': [],
#  'error_message': 'The provided API key is invalid.',
#  'status': 'REQUEST_DENIED'}

# %%
data.keys()
# Out:
# dict_keys(['candidates', 'status'])

# %%
pprint(data)
# Out:
# {'candidates': [{'formatted_address': 'Kankaria Lake, Kankaria, Ahmedabad, '
#                                       'Gujarat 380002',
#                  'geometry': {'location': {'lat': 23.0062573,
#                                            'lng': 72.60255029999999},
#                               'viewport': {'northeast': {'lat': 23.0089099,
#                                                          'lng': 72.6040788},
#                                            'southwest': {'lat': 23.0035204,
#                                                          'lng': 72.5982959}}},
#                  'name': 'Kankaria Lake',
#                  'photos': [{'height': 4000,
#                              'html_attributions': ['<a '
#                                                    'href="https://maps.google.com/maps/contrib/111360837135842626729/photos">Gaurav '
#                                                    'Vishwakarma</a>'],
# ...

# %%
data['candidates'][0].keys()
# Out:
# dict_keys(['formatted_address', 'geometry', 'name', 'photos', 'rating'])

# %%
data['candidates'][0]['formatted_address']
# Out:
# 'Kankaria Lake, Kankaria, Ahmedabad, Gujarat 380002'

# %%
photo = data['candidates'][0]['photos'][0]['photo_reference']

# %%
url2 = f"https://maps.googleapis.com/maps/api/place/photo?maxwidth=400&photoreference={photo}&key={key}"

# %%
print(url2)
# Out:
# https://maps.googleapis.com/maps/api/place/photo?maxwidth=400&photoreference=CmRaAAAAL5YSsdbhX9oAfoZPNG0D1MjWJB_-hOWWFeTbHP2XIP1WuWjXtKd157WmTHG9AKr8F8opq_f3n2bXQlYB3FcPGi2Wv49IGujDba2TjYy-VhB1KivC3GiomyFHS_3dv4SfEhANm_jQexctkbmmeQlP9wSVGhSRHqhdG3cTpDl7eD-Lf45f2cScTA&key=AIzaSyC_iU0HzEiiVfCcyXSxnBQg56_B4HKaVG0

# %%
from PIL import Image

# %%
imreq = requests.get(url2)

# %%
imreq
# Out:
# <Response [200]>

# %%
file = open('myimage.jpg','wb')
file.write(imreq.content)
file.close()

# %%
i = Image.open('myimage.jpg')

# %%
i
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x267 at 0x1AAC7863518>
